# %%
import pandas as pd
import numpy as np
import re
from pandas import DataFrame

# %%
df1 = pd.read_csv('C:/Users/JW/Desktop/12.csv')
df1.drop(['기간','계','소득(구별)','인구비','지역내총생산(당해년가격)','기간.1','자치구.1','Unnamed: 7'],axis=1,inplace=True)
df1.rename(columns={'동':'읍면동명'},inplace=True)
df1.읍면동명 = df1.읍면동명.apply(lambda x: re.sub(r'·', '.', str(x)))
df2=df1[df1.읍면동명 !="소계"]
df2
# Out:
#      자치구         읍면동명      소득(동별)
# 1    종로구          사직동  1,516,420
# 2    종로구          삼청동    504,412
# 3    종로구          부암동  1,661,303
# 4    종로구          평창동  2,868,128
# 5    종로구          무악동  1,244,457
# 6    종로구          교남동  1,207,404
# 7    종로구          가회동    798,954
# 8    종로구  종로1.2.3.4가동  1,300,326
# 9    종로구      종로5.6가동    931,823
# 10   종로구          이화동  1,378,050
# 11   종로구         창신1동  1,109,996
# 12   종로구         창신2동  1,734,540
# 13   종로구         창신3동  1,230,562
# 14   종로구         숭인1동  1,113,325
# 15   종로구         숭인2동  1,383,695
# 16   종로구        청운효자동  2,202,767
# 17   종로구          혜화동  2,874,931
# 19    중구          소공동    576,915
# 20    중구          회현동  2,152,311
# 21    중구           명동  1,345,154
# 22    중구           필동  1,631,649
# 23    중구          장충동  2,024,108
# 24    중구          광희동  2,112,738
# 25    중구         을지로동    678,300
# 26    중구         신당1동  3,049,735
# 27    중구         신당2동  5,477,748
# 28    중구         신당3동  6,422,594
# ...

# %%
df3=pd.read_csv('C:/Users/JW/Desktop/16.csv')
df3.drop(['인구','소득(구별)','인구비'],axis=1,inplace=True)
df3.rename(columns={'행정동':'읍면동명'},inplace=True)
df3.읍면동명 = df3.읍면동명.apply(lambda x: re.sub(r'·', '.', str(x)))
df4=df3[df3.읍면동명 !="소계"]
df4
# Out:
#      자치구         읍면동명      소득(동별)
# 1    종로구          사직동  1,669,880
# 2    종로구          삼청동    518,696
# 3    종로구          부암동  1,811,906
# 4    종로구          평창동  3,241,634
# 5    종로구          무악동  1,505,475
# 6    종로구          교남동  1,855,633
# 7    종로구          가회동    772,449
# 8    종로구  종로1.2.3.4가동  1,485,677
# 9    종로구      종로5.6가동    984,197
# 10   종로구          이화동  1,474,659
# 11   종로구         창신1동  1,049,787
# 12   종로구         창신2동  1,691,399
# 13   종로구         창신3동  1,260,501
# 14   종로구         숭인1동  1,138,445
# 15   종로구         숭인2동  1,716,706
# 16   종로구        청운효자동  2,253,478
# 17   종로구          혜화동  3,606,253
# 19    중구          소공동  1,084,082
# 20    중구          회현동  2,087,703
# 21    중구           명동  1,245,003
# 22    중구           필동  1,799,327
# 23    중구          장충동  2,003,682
# 24    중구          광희동  2,214,803
# 25    중구         을지로동    712,753
# 26    중구         신당5동  3,861,397
# 27    중구          황학동  4,866,442
# 28    중구          중림동  4,630,756
# ...
