# %%
import pandas as pd
import numpy as np
import re
from pandas import Series,DataFrame

# %%
df=pd.read_csv('C:/Users/bookair/Documents/GitHub/Data_GongHak/data/김호성자료,0812선거자료/16년은행.txt', sep='\s+')

# %% [markdown]
# 데이터 간단하기 때문에 탐색 생략하고 기간, 자치구, 동,금융기관 열만 남기겠음.

# %%
df
# Out:
#        기간  자치구            동   금융기관 금융기관.1 금융기관.2  금융기관.3  금융기관.4 금융기관.5  \
# 0      기간  자치구            동     합계   한국은행   시중은행    시중은행    시중은행   시중은행
# 1      기간  자치구            동     합계   한국은행   우리은행  SC제일은행  KB국민은행   신한은행
# 2    2016   합계           합계  2,294      2    410     110     405    351
# 3    2016  종로구           소계    130      -     22       5      23     18
# 4    2016  종로구          사직동     21      -      2       -       2      2
# 5    2016  종로구          삼청동      5      -      2       -       -      1
# 6    2016  종로구          부암동      2      -      1       -       1      -
# 7    2016  종로구          평창동      5      -      1       -       1      1
# 8    2016  종로구          무악동      1      -      -       -       -      -
# 9    2016  종로구          교남동      1      -      -       -       1      -
# 10   2016  종로구          가회동      3      -      -       -       -      2
# 11   2016  종로구  종로1.2.3.4가동     54      -      8       4      11      4
# ...

# %%
df1=df[['자치구','동','금융기관']]

# %%
df1
# Out:
#      자치구            동   금융기관
# 0    자치구            동     합계
# 1    자치구            동     합계
# 2     합계           합계  2,294
# 3    종로구           소계    130
# 4    종로구          사직동     21
# 5    종로구          삼청동      5
# 6    종로구          부암동      2
# 7    종로구          평창동      5
# 8    종로구          무악동      1
# 9    종로구          교남동      1
# 10   종로구          가회동      3
# 11   종로구  종로1.2.3.4가동     54
# 12   종로구      종로5.6가동     11
# 13   종로구          이화동      7
# 14   종로구         창신1동      5
# 15   종로구         창신2동      1
# 16   종로구         숭인1동      1
# 17   종로구         숭인2동      4
# 18   종로구        청운효자동      4
# 19   종로구          혜화동      5
# 20    중구           소계    201
# 21    중구          소공동     37
# 22    중구          회현동     25
# 23    중구           명동     75
# 24    중구           필동      7
# 25    중구          장충동      5
# 26    중구          광희동     16
# 27    중구         을지로동     11
# 28    중구         신당5동      2
# 29    중구          황학동      5
# ..   ...          ...    ...
# ...

# %% [markdown]
# 열이름 '동'을 '읍면동면'으로 바꿔줌

# %%
df1.rename(columns={'동':'읍면동명'},inplace=True)
# Out:
# C:\Users\bookair\Anaconda3\lib\site-packages\pandas\core\frame.py:4025: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   return super(DataFrame, self).rename(**kwargs)

# %%
df1=df1.drop([0,1,2],0)

# %% [markdown]
# 필요없는 행 2개 삭제

# %%
df1
# Out:
#      자치구         읍면동명 금융기관
# 3    종로구           소계  130
# 4    종로구          사직동   21
# 5    종로구          삼청동    5
# 6    종로구          부암동    2
# 7    종로구          평창동    5
# 8    종로구          무악동    1
# 9    종로구          교남동    1
# 10   종로구          가회동    3
# 11   종로구  종로1.2.3.4가동   54
# 12   종로구      종로5.6가동   11
# 13   종로구          이화동    7
# 14   종로구         창신1동    5
# 15   종로구         창신2동    1
# 16   종로구         숭인1동    1
# 17   종로구         숭인2동    4
# 18   종로구        청운효자동    4
# 19   종로구          혜화동    5
# 20    중구           소계  201
# 21    중구          소공동   37
# 22    중구          회현동   25
# 23    중구           명동   75
# 24    중구           필동    7
# 25    중구          장충동    5
# 26    중구          광희동   16
# 27    중구         을지로동   11
# 28    중구         신당5동    2
# 29    중구          황학동    5
# 30    중구          중림동    2
# 31    중구          신당동    7
# 32    중구          다산동    4
# ..   ...          ...  ...
# 390  송파구         가락본동   10
# 391  송파구         가락1동    5
# ...

# %%
df1=df1.reset_index()

# %%
df1
# Out:
#      index  자치구         읍면동명 금융기관
# 0        3  종로구           소계  130
# 1        4  종로구          사직동   21
# 2        5  종로구          삼청동    5
# 3        6  종로구          부암동    2
# 4        7  종로구          평창동    5
# 5        8  종로구          무악동    1
# 6        9  종로구          교남동    1
# 7       10  종로구          가회동    3
# 8       11  종로구  종로1.2.3.4가동   54
# 9       12  종로구      종로5.6가동   11
# 10      13  종로구          이화동    7
# 11      14  종로구         창신1동    5
# 12      15  종로구         창신2동    1
# 13      16  종로구         숭인1동    1
# 14      17  종로구         숭인2동    4
# 15      18  종로구        청운효자동    4
# 16      19  종로구          혜화동    5
# 17      20   중구           소계  201
# 18      21   중구          소공동   37
# 19      22   중구          회현동   25
# 20      23   중구           명동   75
# 21      24   중구           필동    7
# 22      25   중구          장충동    5
# 23      26   중구          광희동   16
# 24      27   중구         을지로동   11
# 25      28   중구         신당5동    2
# ...

# %%
df1=df1.drop('index',1)

# %%
df1
# Out:
#      자치구         읍면동명 금융기관
# 0    종로구           소계  130
# 1    종로구          사직동   21
# 2    종로구          삼청동    5
# 3    종로구          부암동    2
# 4    종로구          평창동    5
# 5    종로구          무악동    1
# 6    종로구          교남동    1
# 7    종로구          가회동    3
# 8    종로구  종로1.2.3.4가동   54
# 9    종로구      종로5.6가동   11
# 10   종로구          이화동    7
# 11   종로구         창신1동    5
# 12   종로구         창신2동    1
# 13   종로구         숭인1동    1
# 14   종로구         숭인2동    4
# 15   종로구        청운효자동    4
# 16   종로구          혜화동    5
# 17    중구           소계  201
# 18    중구          소공동   37
# 19    중구          회현동   25
# 20    중구           명동   75
# 21    중구           필동    7
# 22    중구          장충동    5
# 23    중구          광희동   16
# 24    중구         을지로동   11
# 25    중구         신당5동    2
# 26    중구          황학동    5
# 27    중구          중림동    2
# 28    중구          신당동    7
# 29    중구          다산동    4
# ..   ...          ...  ...
# 387  송파구         가락본동   10
# 388  송파구         가락1동    5
# ...

# %%
df1.to_csv('C:/Users/bookair/Documents/GitHub/Data_GongHak/data/김호성자료,0812선거자료/16년은행.csv')
